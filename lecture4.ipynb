# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.preprocessing import StandardScaler

df=pd.read_csv("C:\\Users\\hp\\Documents\\Python\\SalaryData.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X=df[['YearsExperience']]
y=df[['Salary']]
X_train,X_test, y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
X_train,X_test,y_train,y_test
# Out:
# (    YearsExperience
#  27              9.6
#  11              4.0
#  17              5.3
#  22              7.9
#  5               2.9
#  16              5.1
#  8               3.2
#  14              4.5
#  23              8.2
#  20              6.8
#  1               1.3
#  29             10.5
#  6               3.0
#  4               2.2
#  18              5.9
#  19              6.0
#  9               3.7
#  7               3.2
#  25              9.0
#  3               2.0
#  0               1.1
#  21              7.1
#  15              4.9
#  12              4.0,
#      YearsExperience
#  2               1.5
#  28             10.3
#  13              4.1
#  10              3.9
#  26              9.5
#  24              8.7,
#        Salary
#  27  112635.0
#  11   55794.0
#  17   83088.0
#  22  101302.0
#  5    56642.0
#  16   66029.0
#  8    64445.0
#  14   61111.0
#  23  113812.0
#  20   91738.0
#  1    46205.0
#  29  121872.0
#  6    60150.0
#  4    39891.0
#  18   81363.0
#  19   93940.0
#  9    57189.0
#  7    54445.0
#  25  105582.0
#  3    43525.0
#  0    39343.0
#  21   98273.0
#  15   67938.0
#  12   56957.0,
#        Salary
#  2    37731.0
#  28  122391.0
#  13   57081.0
#  10   63218.0
#  26  116969.0
#  24  109431.0)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# y_pred=model.predict(X_test)

# %%
y_pred=model.predict(X_test)

# %%
print("intercept: ",model.intercept_)
print("coefficient: ", model.coef_)
print("r2 score:" , r2_score(y_test,y_pred))
print("mean square error:" , mean_squared_error(y_test,y_pred))
# Out:
# intercept:  [26780.09915063]
# coefficient:  [[9312.57512673]]
# r2 score: 0.988169515729126
# mean square error: 12823412.298126549

# %%
model.predict([[5]])
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[73342.97478427]])

# %%
plt.scatter(X,y,color='blue')
plt.plot(X,model.predict(X),color='red')
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
# Out:
# Text(0.5, 1.0, 'Experience vs Salary')

# %%
e=5
e_array=np.array([[e]])
p_salary=model.predict(e_array)
print(f"Predicted salary for {e} years of experience is {p_salary[0][0]}")
# Out:
# Predicted salary for 5 years of experience is 73342.97478427412
# c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
