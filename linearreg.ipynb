# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder

import matplotlib.pyplot as plt

df=pd.read_csv('SalaryData.csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]
x
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

lr=LinearRegression()
lr.fit(x_train,y_train)
x_test
# Out:
#     YearsExperience
# 27              9.6
# 15              4.9
# 23              8.2
# 17              5.3
# 8               3.2
# 9               3.7

# %%
y_test
# Out:
# 27    112635.0
# 15     67938.0
# 23    113812.0
# 17     83088.0
# 8      64445.0
# 9      57189.0
# Name: Salary, dtype: float64

# %%
lr.predict(x_test.iloc[0:1])
# Out:
# array([115790.21011287])

# %%
plt.scatter(x,y,color='blue')
plt.plot(x,lr.predict(x),color='red')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Experience vs Salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.scatter(x,y,color='blue')
#       2 plt.plot(x,lr.predict(x),color='red')
#       3 plt.xlabel('Years of Experience')
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:3948, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3928 @_copy_docstring_and_deprecators(Axes.scatter)
#    3929 def scatter(
#    3930     x: float | ArrayLike,
#    (...)   3946     **kwargs,
#    3947 ) -> PathCollection:
# -> 3948     __ret = gca().scatter(
#    3949         x,
#    3950         y,
#    3951         s=s,
#    3952         c=c,
#    3953         marker=marker,
#    3954         cmap=cmap,
#    3955         norm=norm,
#    3956         vmin=vmin,
#    3957         vmax=vmax,
#    3958         alpha=alpha,
#    3959         linewidths=linewidths,
#    3960         edgecolors=edgecolors,
#    3961         colorizer=colorizer,
#    3962         plotnonfinite=plotnonfinite,
#    3963         **({"data": data} if data is not None else {}),
#    3964         **kwargs,
#    3965     )
#    3966     sci(__ret)
#    3967     return __ret
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:2784, in gca()
#    2782 @_copy_docstring_and_deprecators(Figure.gca)
#    2783 def gca() -> Axes:
# -> 2784     return gcf().gca()
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:1107, in gcf()
#    1105     return manager.canvas.figure
#    1106 else:
# -> 1107     return figure()
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:1041, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1031 if len(allnums) == max_open_warning >= 1:
#    1032     _api.warn_external(
#    1033         f"More than {max_open_warning} figures have been opened. "
#    1034         f"Figures created through the pyplot interface "
#    (...)   1038         f"Consider using `matplotlib.pyplot.close()`.",
#    1039         RuntimeWarning)
# -> 1041 manager = new_figure_manager(
#    1042     num, figsize=figsize, dpi=dpi,
#    1043     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#    1044     FigureClass=FigureClass, **kwargs)
#    1045 fig = manager.canvas.figure
#    1046 if fig_label:
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:550, in new_figure_manager(*args, **kwargs)
#     548 def new_figure_manager(*args, **kwargs):
#     549     """Create a new figure manager instance."""
# --> 550     _warn_if_gui_out_of_main_thread()
#     551     return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:527, in _warn_if_gui_out_of_main_thread()
#     525 def _warn_if_gui_out_of_main_thread() -> None:
#     526     warn = False
# --> 527     canvas_class = cast(type[FigureCanvasBase], _get_backend_mod().FigureCanvas)
#     528     if canvas_class.required_interactive_framework:
#     529         if hasattr(threading, 'get_native_id'):
#     530             # This compares native thread ids because even if Python-level
#     531             # Thread objects match, the underlying OS thread (which is what
#     532             # really matters) may be different on Python implementations with
#     533             # green threads.
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:368, in _get_backend_mod()
#     359 """
#     360 Ensure that a backend is selected and return it.
#     361
#     362 This is currently private, but may be made public in the future.
#     363 """
#     364 if _backend_mod is None:
#     365     # Use rcParams._get("backend") to avoid going through the fallback
#     366     # logic (which will (re)import pyplot and then call switch_backend if
#     367     # we need to resolve the auto sentinel)
# --> 368     switch_backend(rcParams._get("backend"))
#     369 return cast(type[matplotlib.backend_bases._Backend], _backend_mod)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:424, in switch_backend(newbackend)
#     421         return
#     422 old_backend = rcParams._get('backend')  # get without triggering backend resolution
# --> 424 module = backend_registry.load_backend_module(newbackend)
#     425 canvas_class = module.FigureCanvas
#     427 required_framework = canvas_class.required_interactive_framework
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\backends\registry.py:317, in BackendRegistry.load_backend_module(self, backend)
#     303 """
#     304 Load and return the module containing the specified backend.
#     305
#    (...)    314     Module containing backend.
#     315 """
#     316 module_name = self._backend_module_name(backend)
# --> 317 return importlib.import_module(module_name)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1396 if level > 0:
#    1397     name = _resolve_name(name, package, level)
# -> 1398 return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1369     module = sys.modules.get(name, _NEEDS_LOADING)
#    1370     if module is _NEEDS_LOADING:
# -> 1371         return _find_and_load_unlocked(name, import_)
#    1373 # Optimization: only call _bootstrap._lock_unlock_module() if
#    1374 # module.__spec__._initializing is True.
#    1375 # NOTE: because of this, initializing must be set *before*
#    1376 # putting the new module in sys.modules.
#    1377 _lock_unlock_module(name)
#
# File <frozen importlib._bootstrap>:1314, in _find_and_load_unlocked(name, import_)
#    1312 if parent:
#    1313     if parent not in sys.modules:
# -> 1314         _call_with_frames_removed(import_, parent)
#    1315     # Crazy side-effects!
#    1316     module = sys.modules.get(name)
#
# File <frozen importlib._bootstrap>:491, in _call_with_frames_removed(f, *args, **kwds)
#     483 def _call_with_frames_removed(f, *args, **kwds):
#     484     """remove_importlib_frames in import.c will always remove sequences
#     485     of importlib frames that end with a call to this function
#     486
#    (...)    489     module code)
#     490     """
# --> 491     return f(*args, **kwds)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1396 if level > 0:
#    1397     name = _resolve_name(name, package, level)
# -> 1398 return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1369     module = sys.modules.get(name, _NEEDS_LOADING)
#    1370     if module is _NEEDS_LOADING:
# -> 1371         return _find_and_load_unlocked(name, import_)
#    1373 # Optimization: only call _bootstrap._lock_unlock_module() if
#    1374 # module.__spec__._initializing is True.
#    1375 # NOTE: because of this, initializing must be set *before*
#    1376 # putting the new module in sys.modules.
#    1377 _lock_unlock_module(name)
#
# File <frozen importlib._bootstrap>:1342, in _find_and_load_unlocked(name, import_)
#    1340     parent_spec._uninitialized_submodules.append(child)
#    1341 try:
# -> 1342     module = _load_unlocked(spec)
#    1343 finally:
#    1344     if parent_spec:
#
# File <frozen importlib._bootstrap>:938, in _load_unlocked(spec)
#     935             raise ImportError('missing loader', name=spec.name)
#     936         # A namespace package so do nothing.
#     937     else:
# --> 938         spec.loader.exec_module(module)
#     939 except:
#     940     try:
#
# File <frozen importlib._bootstrap_external>:762, in _LoaderBasics.exec_module(self, module)
#     759 if code is None:
#     760     raise ImportError(f'cannot load module {module.__name__!r} when '
#     761                       'get_code() returns None')
# --> 762 _bootstrap._call_with_frames_removed(exec, code, module.__dict__)
#
# File <frozen importlib._bootstrap>:491, in _call_with_frames_removed(f, *args, **kwds)
#     483 def _call_with_frames_removed(f, *args, **kwds):
#     484     """remove_importlib_frames in import.c will always remove sequences
#     485     of importlib frames that end with a call to this function
#     486
#    (...)    489     module code)
#     490     """
# --> 491     return f(*args, **kwds)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib_inline\__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.7"  # noqa
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib_inline\backend_inline.py:8
#       6 import matplotlib
#       7 from matplotlib import colors
# ----> 8 from matplotlib.backends import backend_agg
#       9 from matplotlib.backends.backend_agg import FigureCanvasAgg
#      10 from matplotlib._pylab_helpers import Gcf
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\backends\backend_agg.py:38
#      36 from matplotlib.path import Path
#      37 from matplotlib.transforms import Bbox, BboxBase
# ---> 38 from matplotlib.backends._backend_agg import RendererAgg as _RendererAgg
#      41 def get_hinting_flag():
#      42     mapping = {
#      43         'default': LoadFlags.DEFAULT,
#      44         'no_autohint': LoadFlags.NO_AUTOHINT,
#    (...)     52         'none': LoadFlags.NO_HINTING,
#      53     }
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import r2_score
y_pred=lr.predict(x_test)
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.9024461774180497

# %%
from sklearn.metrics import accuracy_score
a=accuracy_score(y_test,y_pred)
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from sklearn.metrics import accuracy_score
# ----> 2 a=accuracy_score(y_test,y_pred)
#       3 print(a)
#
# NameError: name 'y_test' is not defined
