# %% [markdown]
# ✅ What is Feature Scaling?
# Feature scaling is the process of transforming all numerical features to a similar scale.
# Feature scaling is one of the MOST important preprocessing steps in machine learning — especially for algorithms that use distance, gradients, or magnitude of features.
# Without scaling:
# Features with large values dominate
# Model becomes biased
# Accuracy decreases
# 1️⃣ Standardization (StandardScaler) = mean = 0, standard deviation = 1,values around -3 to +3
# 2️⃣ Normalization (MinMaxScaler) = Scales values to 0–1 range.

# %% [markdown]
# KNN is a supervised machine learning algorithm used for:
# Classification (predicting categories)
# Regression (predicting numbers)
# It is a lazy learning algorithm → no training phase (model stores data and uses it during prediction).
# Important Notes Before Using KNN
# Features must be in similar scales→ Use StandardScaler()
# Works poorly with high-dimensional data
# Sensitive to outliers
# K must be chosen carefully (odd number for classification)

# %% [markdown]
# 🎯 Why Encoding?
# Machine learning models cannot understand text. So we convert categorical data → numerical data
# This process is called encoding.
# 🔵 1. Label Encoding--Label Encoding converts each category into a unique integer.
# Use it when the categories have order
# 🟩 2. One Hot Encoding--One Hot Encoding creates separate columns for each category, with 0 or 1.
# Use it when the categories have no order

# %% [markdown]
# Accuracy score
# proportion of correct prediction made out by model of all prediction
# we can not tell how many time model is incorrect
#
# confusion matrix
# shows TN,TP,FN,FP distribution
# FALSE POSITIVE = Type I error
# FALSE NEGATIVE = where we predicted no but it is true= Type II error
#
#
#
# Precision
# how many predicted positives are correct
# precision-TP/(TP+FP)
#
# Recall
# TP/(TP+FN)
# how many actual positives were correctly identified
# when missing a pos case is more costke than false positivve
#
# F1= 2*(Precision *Recall)/(Precision+Recall)
# balances precision and recall into one metric
# it can be used with logistic regression
# its ranges [0,1]

# %% [markdown]
# 📘 What is Linear Regression?
# Linear Regression is a supervised machine learning algorithm used to predict a continuous value (numbers).
# It learns the relationship between:
# X → Input features
# Y → Output (target)
# by fitting a straight line.
