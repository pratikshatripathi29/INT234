# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='whitegrid')

# %%
# Load the Iris dataset (file in workspace root)
df = pd.read_csv('Iris.csv') if 'Iris.csv' in pd.io.common._get_handle.__globals__ else pd.read_csv('Iris.csv')
# If the CSV has an index column named 'Id' or similar, drop it if present
if 'Id' in df.columns:
    df = df.drop(columns=['Id'])
print(df.head())

# %%
# Prepare features and target
X = df.select_dtypes(include=[np.number])
y = df.select_dtypes(exclude=[np.number]).iloc[:, 0] if df.select_dtypes(exclude=[np.number]).shape[1] > 0 else None
# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
: 
,
: {
: 

: [
,
,
,
,
,
4
,
,
,
,
,

: 
,
: {
: 

: [
,
1
,
