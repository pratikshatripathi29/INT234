# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\hp\\Downloads\\ecommerce_customers_unit1.csv")

s=df.isna()
a=df.isna().sum().sort_values()

# %%
import matplotlib.pyplot as plt
plt.bar(a.index,a)
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['age'].quantile(0.25)
q3=df['age'].quantile(0.75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
outliers=df[(df['age']<lb ) | (df['age']>ub)]
print(outliers)
# Out:
# Empty DataFrame
# Columns: [customer_id, age, gender, country, signup_date, last_purchase_date, num_orders, total_spent, avg_order_value, recency_days, is_premium_member, device_type, preferred_category, churned]
# Index: []

# %%
df.select_dtypes
# Out:
# <bound method DataFrame.select_dtypes of      customer_id   age  gender  country signup_date last_purchase_date  \
# 0          10001  56.0    Male    India  2022-01-27         2024-04-27
# 1          10002  69.0   Other       UK  2025-01-12         2025-08-01
# 2          10003  46.0  Female      USA  2021-04-25         2021-06-01
# 3          10004  32.0    Male    India  2021-02-23         2023-09-22
# 4          10005  60.0  Female    India  2021-06-07         2021-12-11
# ..           ...   ...     ...      ...         ...                ...
# 600        10358  25.0  Female    India  2023-09-04         2025-06-18
# 601        10117  50.0    Male      USA  2024-05-11         2024-11-08
# 602        10599  46.0    Male    India  2020-12-01         2024-06-25
# 603        10442  32.0  Female       UK  2023-12-20         2024-09-20
# 604        10555  44.0  Female  Germany  2024-06-16         2024-12-09
#
#      num_orders  total_spent  avg_order_value  recency_days  \
# ...

# %%
q1=df['age'].quantile(0.25)
q3=df['age'].quantile(0.75)
iqr=q3-q1
iqr
# Out:
# np.float64(24.0)

# %%
t=df['age'].fillna(value=df['age'].mean())
t
# Out:
# 0      56.0
# 1      69.0
# 2      46.0
# 3      32.0
# 4      60.0
#        ...
# 600    25.0
# 601    50.0
# 602    46.0
# 603    32.0
# 604    44.0
# Name: age, Length: 605, dtype: float64

# %%
df['age']=(df['age']-df['age'].min())/(df['age'].max()-df['age'].min())
df['age']
# Out:
# 0      0.745098
# 1      1.000000
# 2      0.549020
# 3      0.274510
# 4      0.823529
#          ...
# 600    0.137255
# 601    0.627451
# 602    0.549020
# 603    0.274510
# 604    0.509804
# Name: age, Length: 605, dtype: float64

# %%
df['age']=(df['age']-df['age'].mean())/df['age'].std()
df['age']
# Out:
# 0      0.789448
# 1      1.657343
# 2      0.121836
# 3     -0.812820
# 4      1.056493
#          ...
# 600   -1.280148
# 601    0.388881
# 602    0.121836
# 603   -0.812820
# 604   -0.011686
# Name: age, Length: 605, dtype: float64

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler,StandardScaler
data={'Age':[23,45,66,87],
    'Income':[45,32,65,87]}
dt=pd.DataFrame(data)
norm=MinMaxScaler()
dt_norm=pd.DataFrame(norm.fit_transform(dt),columns=dt.columns)
std=StandardScaler()
dt_std=pd.DataFrame(std.fit_transform(dt),columns=dt.columns)
print(dt)
print(dt_norm)
print(dt_std)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.preprocessing import MinMaxScaler,StandardScaler
#       3 data={'Age':[23,45,66,87],
#       4     'Income':[45,32,65,87]}
#       5 dt=pd.DataFrame(data)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df_norm=pd.DataFrame(norm.fit_transform(df),coluns=df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_norm=pd.DataFrame(norm.fit_transform(df),coluns=df.columns)
#
# NameError: name 'norm' is not defined
