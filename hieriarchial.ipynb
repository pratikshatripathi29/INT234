# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.datasets import load_iris
iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df["species"]=iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
X=df.drop("species",axis=1)

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
plt.figure(figsize=(10, 6))
linked=linkage(X_scaled, method='ward')
dendrogram(linked)
plt.title('Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Euclidean distances')
plt.show()

# %%
hc=AgglomerativeClustering(n_clusters=3, linkage='ward')
df['cluster']=hc.fit_predict(X_scaled)
df["cluster"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    0
# 146    0
# 147    0
# 148    0
# 149    0
# Name: cluster, Length: 150, dtype: int64

# %% [markdown]
# T1	A	B	C		RULE        	Support	     Confidence	                Lift
# T2	A	C	D		A=>D	         2/5	        2/3	                    10/9
# T3	B	C	D		C=>A	         2/5        	2/4	                     5/6
# T4	A	D	E		A=>C	         2/5	        2/3	                     5/6
# T5	B	C	E		B&C=>A	         1/5	        1/3	                     5/9
#                                  freq(A,B)/N    freq(A,B)/freq(A)	confidence(A,B)/support(B)
